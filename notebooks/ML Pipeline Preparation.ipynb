# %% [markdown]
# # ML Pipeline Preparation
# Follow the instructions below to help you create your ML pipeline.
# ### 1. Import libraries and load data from database.
# - Import Python libraries
# - Load dataset from database with [`read_sql_table`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_sql_table.html)
# - Define feature and target variables X and Y

# %%
import sys
sys.path.append('../models')  # Add the path to the models directory
import train_classifier

import joblib

# Now you can use the methods from train_classifier.py
# Example: train_classifier.load_data()
X, Y, category_names = train_classifier.load_data('../data/DisasterResponse.db')

X.head()
Y.head()
category_names
# Out:
# [nltk_data] Downloading package punkt to /home/codespace/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /home/codespace/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/codespace/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Index(['related', 'request', 'offer', 'aid_related', 'medical_help',
#        'medical_products', 'search_and_rescue', 'security', 'military',
#        'child_alone', 'water', 'food', 'shelter', 'clothing', 'money',
#        'missing_people', 'refugees', 'death', 'other_aid',
#        'infrastructure_related', 'transport', 'buildings', 'electricity',
#        'tools', 'hospitals', 'shops', 'aid_centers', 'other_infrastructure',
#        'weather_related', 'floods', 'storm', 'fire', 'earthquake', 'cold',
#        'other_weather', 'direct_report'],
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)

# %%
        
print('Building model...')
# base model
model = train_classifier.build_model()

# wrap with grid search
# beware that this will take a long time to run (>70min)
# model = train_classifier.wrap_gridSerach(model)
      
      
  
print('Training model...')
model.fit(X_train, Y_train)
# Out:
# Building model...
# Training model...
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [nltk_data] Downloading package punkt to /home/codespace/nltk_data...[nltk_data] Downloading package punkt to /home/codespace/nltk_data...
#
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /home/codespace/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /home/codespace/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/codespace/nltk_data...
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/codespace/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data]   Package wordnet is already up-to-date!
# ...

# %%
# save model
joblib.dump(model, 'model.pkl')
# Out:
# ['model.pkl']

# %%
# load model
model = joblib.load("model.pkl")

# %%
from sklearn.metrics import classification_report
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

print('Evaluating model...')
Y_pred = model.predict(X_test)




for i, category in enumerate(category_names):
    print('Category: {}'.format(category))
    print('Type of my_test:', type(Y_test))
    print('Type of my_pred:', type(Y_pred))
    my_test = Y_test.values[:,i]
    my_pred = Y_pred[:,i]
    cat_report = classification_report(my_test, my_pred, output_dict=True)
    sns.heatmap(pd.DataFrame(cat_report).iloc[:-1, :].T, annot=True)
    plt.title('Classification report for category: {}'.format(category))
    plt.show()
# Out:
# Evaluating model...
# Category: related
# Type of my_test: <class 'pandas.core.frame.DataFrame'>
# Type of my_pred: <class 'numpy.ndarray'>
# Category: request
# Type of my_test: <class 'pandas.core.frame.DataFrame'>
# Type of my_pred: <class 'numpy.ndarray'>
# Category: offer
# Type of my_test: <class 'pandas.core.frame.DataFrame'>
# Type of my_pred: <class 'numpy.ndarray'>
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/codespace/.local/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
# use model for prediction

query = ['a Child is missing']

prediction = model.predict(query)

prediction_dict = dict(zip(category_names, prediction[0]))
print(prediction_dict)
# Out:
# {'related': np.int64(1), 'request': np.int64(0), 'offer': np.int64(0), 'aid_related': np.int64(0), 'medical_help': np.int64(0), 'medical_products': np.int64(0), 'search_and_rescue': np.int64(0), 'security': np.int64(0), 'military': np.int64(0), 'child_alone': np.int64(0), 'water': np.int64(0), 'food': np.int64(0), 'shelter': np.int64(0), 'clothing': np.int64(0), 'money': np.int64(0), 'missing_people': np.int64(0), 'refugees': np.int64(0), 'death': np.int64(0), 'other_aid': np.int64(0), 'infrastructure_related': np.int64(0), 'transport': np.int64(0), 'buildings': np.int64(0), 'electricity': np.int64(0), 'tools': np.int64(0), 'hospitals': np.int64(0), 'shops': np.int64(0), 'aid_centers': np.int64(0), 'other_infrastructure': np.int64(0), 'weather_related': np.int64(0), 'floods': np.int64(0), 'storm': np.int64(0), 'fire': np.int64(0), 'earthquake': np.int64(0), 'cold': np.int64(0), 'other_weather': np.int64(0), 'direct_report': np.int64(0)}

# %% [markdown]
# ### 6. Improve your model
# Use grid search to find better parameters.

# %%
parameters = {
        'clf__estimator__n_estimators': [50, 100],
        'clf__estimator__min_samples_split': [2, 4]
    }

optimized = GridSearchCV(model, param_grid=parameters, verbose=3, n_jobs=-1)

# %% [markdown]
# ### 7. Test your model
# Show the accuracy, precision, and recall of the tuned model.
#
# Since this project focuses on code quality, process, and  pipelines, there is no minimum performance metric needed to pass. However, make sure to fine tune your models for accuracy, precision and recall to make your project stand out - especially for your portfolio!

# %% [markdown]
# ### 8. Try improving your model further. Here are a few ideas:
# * try other machine learning algorithms
# * add other features besides the TF-IDF

# %% [markdown]
# ### 9. Export your model as a pickle file

# %%
import pickle

# Save the model to a pickle file
with open('model.pkl', 'wb') as file:
    pickle.dump(model, file)

# %% [markdown]
# ### 10. Use this notebook to complete `train_classifier.py`
# Use the template file attached in the Resources folder to write a script that runs the steps above to create a database and export a model based on a new dataset specified by the user.
